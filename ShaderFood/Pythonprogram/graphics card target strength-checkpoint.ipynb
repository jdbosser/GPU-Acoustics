# %% [markdown]
# ## summation example ##
#
# Imagine a sphere wit radius 2 meter.
# View this through a gitter of points separated distance *d*
#
# For each gitter point there is an associated area $d²$

# %%
from math import *
import numpy as np
import time
import matplotlib.pyplot as plt


# Input parameters

R = 6.0         # radius
f = 2000.0     # frequency
c = 1500.0      # speed of sound

lamda = c/f     # wavelength
k = 2*pi/lamda  # wave number

# other parameters
mmax = 500
n = 2*mmax + 1    # array dimension
step = R/mmax     # steg mellan enskilda punkter (i x eller y)
pixarea = R*R/(n*n)

xs = np.linspace(-R,R,n)
ys = np.linspace(-R,R,n)
elems = np.zeros((n,n), dtype = np.complex128)      # element contributions

# z-koordinaten för punkt (i,j) 
# här tänker jag mig en indexering från -nmax till nmax
def z(R,x,y):
    try:
        sq = sqrt(R*R - x*x - y*y)  
    except:
        print('exception',  R, x ,y)
        sq = 0
    return sq

        
# normalvinkeln för punkt (i,j)
# här tänker jag mig en indexering från -nmax till nmax
def cosfi(R,x,y):
    return z(R,x,y)/R

#projicerad area för en pixel    
# här tänker jag mig en indexering från -nmax till nmax
def projarea(R,x,y):
    return pixarea/cosfi(R,x,y)

def inrange(R,x,y):
    return (x*x + y*y) < (R*R)


def fill_array():
    for i in range(n):
        x = xs[i]
        for j in range(n):
            y = ys[j]
            if inrange(R,x,y):
                try:
#                    a = projarea(x,y)
#                    a = pixarea*cosfi(x,y)
                    a = pixarea
                    val = 4*a/lamda  # intensiteten (varför 4*?)
                    phase = -2*k*(9-z(R,x,y))
                    elems[i,j] = val*complex(cos(phase), sin(phase))
                except:
                    print(x,y,a)


print('lambda', lamda)
start_time = time.time()
fill_array();    
fill_time = time.time()    
res = abs(np.sum(elems))**2
res_time = time.time()
print(res)
print('fill time', (fill_time - start_time))
print('sum time', (res_time - fill_time))
# Out:
# lambda 0.75
# 9.016322069538916
# fill time 1.35750150680542
# sum time 0.0015652179718017578

# %% [markdown]
# Here is a plot

# %%
c = 1500.0 # speed of sound

""" n is the number of points """
def sphere_TS(radius,n,frequency):
    N = 2*trunc(n/2) + 1    # I want an odd number
    lamda = c/frequency
    k = 2*pi/lamda
    xs = np.linspace(-radius,radius,N)
    ys = np.linspace(-radius,radius,N)
    elems = np.zeros((N,N), dtype = np.complex128)      # element contributions
    pixarea = 4*radius*radius/(N*N)    
    """
    print 'n',n
    print 'N',N
    print 'radius',radius
    print 'freq',frequency
    print 'lambda', lamda
    print 'k',k
    """
    print('freq',frequency)
    
    #elems = np.zeros((N,N), dtype = np.complex64)      # element contributions
    for i in range(N):
        x = xs[i]
        for j in range(N):
            y = ys[j]
            if inrange(radius,x,y):
                try:
#                    a = projarea(x,y)
#                    a = pixarea*cosfi(x,y)
                    a = pixarea
                    val = a/lamda  # intensiteten (varför 4*?)
                    phase = -2*k*(999-z(radius,x,y))
                    elems[i,j] = val*complex(cos(phase), sin(phase))
                except:
                    print(x,y,a)
    return abs(np.sum(elems))**2

n = 2000
radius = 2.0

freqs = np.logspace(1,5, num = 10)
print(freqs)
plt.xscale('log')
plt.yscale('log')
print(sphere_TS(2.0,1000,10000.0))

plt.plot(freqs, [sphere_TS(radius,n,f) for f in freqs])
plt.show()
# Out:
# [1.00000000e+01 2.78255940e+01 7.74263683e+01 2.15443469e+02
#  5.99484250e+02 1.66810054e+03 4.64158883e+03 1.29154967e+04
#  3.59381366e+04 1.00000000e+05]
# freq 10000.0
# 1.0310202925221905
# freq 10.0
# freq 27.825594022071243
# freq 77.4263682681127
# freq 215.44346900318823
# freq 599.4842503189409
# freq 1668.100537200059
# freq 4641.588833612777
# freq 12915.496650148827
# freq 35938.13663804626
# freq 100000.0

# %%
def square_TS(a,b,n,frequency,angle = 0.0):
    N = 2*trunc(n/2) + 1    # I want an odd number
    xs = np.linspace(-a/2,a/2,N)
    ys = np.linspace(-b/2,b/2,N)
    lamda = c/frequency
    k = 2*pi/lamda
    elems = np.zeros((N,N), dtype = np.complex64)      # element contributions
    pixarea = a*b/(N*N)
    """
    print 'a',a
    print 'b',b
    print 'lambda', lamda
    print 'pixarea',pixarea
    """
    print angle*180/pi
    
    for i in range(N):
        x = xs[i]
        for j in range(N):
            y = ys[j]
            try:
#                a = projarea(x,y)
                a = pixarea
                val = a*cos(angle)/lamda  # intensiteten (varför inte *4 här)
                phase = -2*k*(x*sin(angle))
                elems[i,j] = val*complex(cos(phase), sin(phase))
            except:
                print x,y,a
    return abs(np.sum(elems))**2

c = 1500.0
a = 2.0
b = 1.02
freq = 10000.0
angle = 0
n = 1000
print square_TS(a,b,n,freq, 0.0)

# ovanstående stämmer bra för vinkeln 0


angles = np.linspace(0,pi/2,900)
plt.plot(angles*180/pi, [10*log10(square_TS(a,b,n,freq,angle)) for angle in angles])
plt.show()
# Out:
# 0.0
# 184.960347595
# 0.0
# 0.100111234705
# 0.20022246941
# 0.300333704116
# 0.400444938821
# 0.500556173526
# 0.600667408231
# 0.700778642937
# 0.800889877642
# 0.901001112347
# 1.00111234705
# 1.10122358176
# 1.20133481646
# 1.30144605117
# 1.40155728587
# 1.50166852058
# 1.60177975528
# 1.70189098999
# 1.80200222469
# 1.9021134594
# 2.0022246941
# 2.10233592881
# 2.20244716352
# 2.30255839822
# 2.40266963293
# 2.50278086763
# 2.60289210234
# 2.70300333704
# 2.80311457175
# 2.90322580645
# 3.00333704116
# 3.10344827586
# 3.20355951057
# 3.30367074527
# 3.40378197998
# 3.50389321468
# 3.60400444939
# 3.70411568409
# 3.8042269188
# 3.9043381535
# 4.00444938821
# 4.10456062291
# 4.20467185762
# 4.30478309232
# 4.40489432703
# 4.50500556174
# 4.60511679644
# 4.70522803115
# 4.80533926585
# 4.90545050056
# 5.00556173526
# 5.10567296997
# 5.20578420467
# 5.30589543938
# 5.40600667408
# 5.50611790879
# 5.60622914349
# 5.7063403782
# 5.8064516129
# 5.90656284761
# 6.00667408231
# 6.10678531702
# 6.20689655172
# 6.30700778643
# 6.40711902113
# 6.50723025584
# 6.60734149055
# 6.70745272525
# 6.80756395996
# 6.90767519466
# 7.00778642937
# 7.10789766407
# 7.20800889878
# 7.30812013348
# 7.40823136819
# 7.50834260289
# 7.6084538376
# 7.7085650723
# 7.80867630701
# 7.90878754171
# 8.00889877642
# 8.10901001112
# 8.20912124583
# 8.30923248053
# 8.40934371524
# 8.50945494994
# 8.60956618465
# 8.70967741935
# 8.80978865406
# 8.90989988877
# 9.01001112347
# 9.11012235818
# 9.21023359288
# 9.31034482759
# 9.41045606229
# 9.510567297
# 9.6106785317
# 9.71078976641
# 9.81090100111
# 9.91101223582
# 10.0111234705
# 10.1112347052
# 10.2113459399
# 10.3114571746
# 10.4115684093
# 10.511679644
# 10.6117908788
# 10.7119021135
# 10.8120133482
# 10.9121245829
# 11.0122358176
# 11.1123470523
# 11.212458287
# 11.3125695217
# 11.4126807564
# 11.5127919911
# 11.6129032258
# 11.7130144605
# 11.8131256952
# 11.9132369299
# 12.0133481646
# 12.1134593993
# 12.213570634
# 12.3136818687
# 12.4137931034
# 12.5139043382
# 12.6140155729
# 12.7141268076
# 12.8142380423
# 12.914349277
# 13.0144605117
# 13.1145717464
# 13.2146829811
# 13.3147942158
# 13.4149054505
# 13.5150166852
# 13.6151279199
# 13.7152391546
# 13.8153503893
# 13.915461624
# 14.0155728587
# 14.1156840934
# 14.2157953281
# 14.3159065628
# 14.4160177976
# 14.5161290323
# 14.616240267
# 14.7163515017
# 14.8164627364
# 14.9165739711
# 15.0166852058
# 15.1167964405
# 15.2169076752
# 15.3170189099
# 15.4171301446
# 15.5172413793
# 15.617352614
# 15.7174638487
# 15.8175750834
# 15.9176863181
# 16.0177975528
# 16.1179087875
# 16.2180200222
# 16.318131257
# 16.4182424917
# 16.5183537264
# 16.6184649611
# 16.7185761958
# 16.8186874305
# 16.9187986652
# 17.0189098999
# 17.1190211346
# 17.2191323693
# 17.319243604
# 17.4193548387
# 17.5194660734
# 17.6195773081
# 17.7196885428
# 17.8197997775
# 17.9199110122
# 18.0200222469
# 18.1201334816
# 18.2202447164
# 18.3203559511
# 18.4204671858
# 18.5205784205
# 18.6206896552
# 18.7208008899
# 18.8209121246
# 18.9210233593
# 19.021134594
# 19.1212458287
# 19.2213570634
# 19.3214682981
# 19.4215795328
# 19.5216907675
# 19.6218020022
# 19.7219132369
# 19.8220244716
# 19.9221357063
# 20.022246941
# 20.1223581758
# 20.2224694105
# 20.3225806452
# 20.4226918799
# 20.5228031146
# 20.6229143493
# 20.723025584
# 20.8231368187
# 20.9232480534
# 21.0233592881
# 21.1234705228
# 21.2235817575
# 21.3236929922
# 21.4238042269
# 21.5239154616
# 21.6240266963
# 21.724137931
# 21.8242491657
# 21.9243604004
# 22.0244716352
# 22.1245828699
# 22.2246941046
# 22.3248053393
# 22.424916574
# 22.5250278087
# 22.6251390434
# 22.7252502781
# 22.8253615128
# 22.9254727475
# 23.0255839822
# 23.1256952169
# 23.2258064516
# 23.3259176863
# 23.426028921
# 23.5261401557
# 23.6262513904
# 23.7263626251
# 23.8264738598
# 23.9265850945
# 24.0266963293
# 24.126807564
# 24.2269187987
# 24.3270300334
# 24.4271412681
# 24.5272525028
# 24.6273637375
# 24.7274749722
# 24.8275862069
# 24.9276974416
# 25.0278086763
# 25.127919911
# 25.2280311457
# 25.3281423804
# 25.4282536151
# 25.5283648498
# 25.6284760845
# 25.7285873192
# 25.8286985539
# 25.9288097887
# 26.0289210234
# 26.1290322581
# 26.2291434928
# 26.3292547275
# 26.4293659622
# 26.5294771969
# 26.6295884316
# 26.7296996663
# 26.829810901
# 26.9299221357
# 27.0300333704
# 27.1301446051
# 27.2302558398
# 27.3303670745
# 27.4304783092
# 27.5305895439
# 27.6307007786
# 27.7308120133
# 27.8309232481
# 27.9310344828
# 28.0311457175
# 28.1312569522
# 28.2313681869
# 28.3314794216
# 28.4315906563
# 28.531701891
# 28.6318131257
# 28.7319243604
# 28.8320355951
# 28.9321468298
# 29.0322580645
# 29.1323692992
# 29.2324805339
# 29.3325917686
# 29.4327030033
# 29.532814238
# 29.6329254727
# 29.7330367075
# 29.8331479422
# 29.9332591769
# 30.0333704116
# 30.1334816463
# 30.233592881
# 30.3337041157
# 30.4338153504
# 30.5339265851
# 30.6340378198
# 30.7341490545
# 30.8342602892
# 30.9343715239
# 31.0344827586
# 31.1345939933
# 31.234705228
# 31.3348164627
# 31.4349276974
# 31.5350389321
# 31.6351501669
# 31.7352614016
# 31.8353726363
# 31.935483871
# 32.0355951057
# 32.1357063404
# 32.2358175751
# 32.3359288098
# 32.4360400445
# 32.5361512792
# 32.6362625139
# 32.7363737486
# 32.8364849833
# 32.936596218
# 33.0367074527
# 33.1368186874
# 33.2369299221
# 33.3370411568
# 33.4371523915
# 33.5372636263
# 33.637374861
# 33.7374860957
# 33.8375973304
# 33.9377085651
# 34.0378197998
# 34.1379310345
# 34.2380422692
# 34.3381535039
# 34.4382647386
# 34.5383759733
# 34.638487208
# 34.7385984427
# 34.8387096774
# 34.9388209121
# 35.0389321468
# 35.1390433815
# 35.2391546162
# 35.3392658509
# 35.4393770857
# 35.5394883204
# 35.6395995551
# 35.7397107898
# 35.8398220245
# 35.9399332592
# 36.0400444939
# 36.1401557286
# 36.2402669633
# 36.340378198
# 36.4404894327
# 36.5406006674
# 36.6407119021
# 36.7408231368
# 36.8409343715
# 36.9410456062
# 37.0411568409
# 37.1412680756
# 37.2413793103
# 37.3414905451
# 37.4416017798
# 37.5417130145
# 37.6418242492
# 37.7419354839
# 37.8420467186
# 37.9421579533
# 38.042269188
# 38.1423804227
# 38.2424916574
# 38.3426028921
# 38.4427141268
# 38.5428253615
# 38.6429365962
# 38.7430478309
# 38.8431590656
# 38.9432703003
# 39.043381535
# 39.1434927697
# 39.2436040044
# 39.3437152392
# 39.4438264739
# 39.5439377086
# 39.6440489433
# 39.744160178
# 39.8442714127
# 39.9443826474
# 40.0444938821
# 40.1446051168
# 40.2447163515
# 40.3448275862
# 40.4449388209
# 40.5450500556
# 40.6451612903
# 40.745272525
# 40.8453837597
# 40.9454949944
# 41.0456062291
# 41.1457174638
# 41.2458286986
# 41.3459399333
# 41.446051168
# 41.5461624027
# 41.6462736374
# 41.7463848721
# 41.8464961068
# 41.9466073415
# 42.0467185762
# 42.1468298109
# 42.2469410456
# 42.3470522803
# 42.447163515
# 42.5472747497
# 42.6473859844
# 42.7474972191
# 42.8476084538
# 42.9477196885
# 43.0478309232
# 43.147942158
# 43.2480533927
# 43.3481646274
# 43.4482758621
# 43.5483870968
# 43.6484983315
# 43.7486095662
# 43.8487208009
# 43.9488320356
# 44.0489432703
# 44.149054505
# 44.2491657397
# 44.3492769744
# 44.4493882091
# 44.5494994438
# 44.6496106785
# 44.7497219132
# 44.8498331479
# 44.9499443826
# 45.0500556174
# 45.1501668521
# 45.2502780868
# 45.3503893215
# 45.4505005562
# 45.5506117909
# 45.6507230256
# 45.7508342603
# 45.850945495
# 45.9510567297
# 46.0511679644
# 46.1512791991
# 46.2513904338
# 46.3515016685
# 46.4516129032
# 46.5517241379
# 46.6518353726
# 46.7519466073
# 46.852057842
# 46.9521690768
# 47.0522803115
# 47.1523915462
# 47.2525027809
# 47.3526140156
# 47.4527252503
# 47.552836485
# 47.6529477197
# 47.7530589544
# 47.8531701891
# 47.9532814238
# 48.0533926585
# 48.1535038932
# 48.2536151279
# 48.3537263626
# 48.4538375973
# 48.553948832
# 48.6540600667
# 48.7541713014
# 48.8542825362
# 48.9543937709
# 49.0545050056
# 49.1546162403
# 49.254727475
# 49.3548387097
# 49.4549499444
# 49.5550611791
# 49.6551724138
# 49.7552836485
# 49.8553948832
# 49.9555061179
# 50.0556173526
# 50.1557285873
# 50.255839822
# 50.3559510567
# 50.4560622914
# 50.5561735261
# 50.6562847608
# 50.7563959956
# 50.8565072303
# 50.956618465
# 51.0567296997
# 51.1568409344
# 51.2569521691
# 51.3570634038
# 51.4571746385
# 51.5572858732
# 51.6573971079
# 51.7575083426
# 51.8576195773
# 51.957730812
# 52.0578420467
# 52.1579532814
# 52.2580645161
# 52.3581757508
# 52.4582869855
# 52.5583982202
# 52.6585094549
# 52.7586206897
# 52.8587319244
# 52.9588431591
# 53.0589543938
# 53.1590656285
# 53.2591768632
# 53.3592880979
# 53.4593993326
# 53.5595105673
# 53.659621802
# 53.7597330367
# 53.8598442714
# 53.9599555061
# 54.0600667408
# 54.1601779755
# 54.2602892102
# 54.3604004449
# 54.4605116796
# 54.5606229143
# 54.6607341491
# 54.7608453838
# 54.8609566185
# 54.9610678532
# 55.0611790879
# 55.1612903226
# 55.2614015573
# 55.361512792
# 55.4616240267
# 55.5617352614
# 55.6618464961
# 55.7619577308
# 55.8620689655
# 55.9621802002
# 56.0622914349
# 56.1624026696
# 56.2625139043
# 56.362625139
# 56.4627363737
# 56.5628476085
# 56.6629588432
# 56.7630700779
# 56.8631813126
# 56.9632925473
# 57.063403782
# 57.1635150167
# 57.2636262514
# 57.3637374861
# 57.4638487208
# 57.5639599555
# 57.6640711902
# 57.7641824249
# 57.8642936596
# 57.9644048943
# 58.064516129
# 58.1646273637
# 58.2647385984
# 58.3648498331
# 58.4649610679
# 58.5650723026
# 58.6651835373
# 58.765294772
# 58.8654060067
# 58.9655172414
# 59.0656284761
# 59.1657397108
# 59.2658509455
# 59.3659621802
# 59.4660734149
# 59.5661846496
# 59.6662958843
# 59.766407119
# 59.8665183537
# 59.9666295884
# 60.0667408231
# 60.1668520578
# 60.2669632925
# 60.3670745273
# 60.467185762
# 60.5672969967
# 60.6674082314
# 60.7675194661
# 60.8676307008
# 60.9677419355
# 61.0678531702
# 61.1679644049
# 61.2680756396
# 61.3681868743
# 61.468298109
# 61.5684093437
# 61.6685205784
# 61.7686318131
# 61.8687430478
# 61.9688542825
# 62.0689655172
# 62.1690767519
# 62.2691879867
# 62.3692992214
# 62.4694104561
# 62.5695216908
# 62.6696329255
# 62.7697441602
# 62.8698553949
# 62.9699666296
# 63.0700778643
# 63.170189099
# 63.2703003337
# 63.3704115684
# 63.4705228031
# 63.5706340378
# 63.6707452725
# 63.7708565072
# 63.8709677419
# 63.9710789766
# 64.0711902113
# 64.1713014461
# 64.2714126808
# 64.3715239155
# 64.4716351502
# 64.5717463849
# 64.6718576196
# 64.7719688543
# 64.872080089
# 64.9721913237
# 65.0723025584
# 65.1724137931
# 65.2725250278
# 65.3726362625
# 65.4727474972
# 65.5728587319
# 65.6729699666
# 65.7730812013
# 65.873192436
# 65.9733036707
# 66.0734149055
# 66.1735261402
# 66.2736373749
# 66.3737486096
# 66.4738598443
# 66.573971079
# 66.6740823137
# 66.7741935484
# 66.8743047831
# 66.9744160178
# 67.0745272525
# 67.1746384872
# 67.2747497219
# 67.3748609566
# 67.4749721913
# 67.575083426
# 67.6751946607
# 67.7753058954
# 67.8754171301
# 67.9755283648
# 68.0756395996
# 68.1757508343
# 68.275862069
# 68.3759733037
# 68.4760845384
# 68.5761957731
# 68.6763070078
# 68.7764182425
# 68.8765294772
# 68.9766407119
# 69.0767519466
# 69.1768631813
# 69.276974416
# 69.3770856507
# 69.4771968854
# 69.5773081201
# 69.6774193548
# 69.7775305895
# 69.8776418242
# 69.977753059
# 70.0778642937
# 70.1779755284
# 70.2780867631
# 70.3781979978
# 70.4783092325
# 70.5784204672
# 70.6785317019
# 70.7786429366
# 70.8787541713
# 70.978865406
# 71.0789766407
# 71.1790878754
# 71.2791991101
# 71.3793103448
# 71.4794215795
# 71.5795328142
# 71.6796440489
# 71.7797552836
# 71.8798665184
# 71.9799777531
# 72.0800889878
# 72.1802002225
# 72.2803114572
# 72.3804226919
# 72.4805339266
# 72.5806451613
# 72.680756396
# 72.7808676307
# 72.8809788654
# 72.9810901001
# 73.0812013348
# 73.1813125695
# 73.2814238042
# 73.3815350389
# 73.4816462736
# 73.5817575083
# 73.681868743
# 73.7819799778
# 73.8820912125
# 73.9822024472
# 74.0823136819
# 74.1824249166
# 74.2825361513
# 74.382647386
# 74.4827586207
# 74.5828698554
# 74.6829810901
# 74.7830923248
# 74.8832035595
# 74.9833147942
# 75.0834260289
# 75.1835372636
# 75.2836484983
# 75.383759733
# 75.4838709677
# 75.5839822024
# 75.6840934372
# 75.7842046719
# 75.8843159066
# 75.9844271413
# 76.084538376
# 76.1846496107
# 76.2847608454
# 76.3848720801
# 76.4849833148
# 76.5850945495
# 76.6852057842
# 76.7853170189
# 76.8854282536
# 76.9855394883
# 77.085650723
# 77.1857619577
# 77.2858731924
# 77.3859844271
# 77.4860956618
# 77.5862068966
# 77.6863181313
# 77.786429366
# 77.8865406007
# 77.9866518354
# 78.0867630701
# 78.1868743048
# 78.2869855395
# 78.3870967742
# 78.4872080089
# 78.5873192436
# 78.6874304783
# 78.787541713
# 78.8876529477
# 78.9877641824
# 79.0878754171
# 79.1879866518
# 79.2880978865
# 79.3882091212
# 79.488320356
# 79.5884315907
# 79.6885428254
# 79.7886540601
# 79.8887652948
# 79.9888765295
# 80.0889877642
# 80.1890989989
# 80.2892102336
# 80.3893214683
# 80.489432703
# 80.5895439377
# 80.6896551724
# 80.7897664071
# 80.8898776418
# 80.9899888765
# 81.0901001112
# 81.1902113459
# 81.2903225806
# 81.3904338154
# 81.4905450501
# 81.5906562848
# 81.6907675195
# 81.7908787542
# 81.8909899889
# 81.9911012236
# 82.0912124583
# 82.191323693
# 82.2914349277
# 82.3915461624
# 82.4916573971
# 82.5917686318
# 82.6918798665
# 82.7919911012
# 82.8921023359
# 82.9922135706
# 83.0923248053
# 83.19243604
# 83.2925472747
# 83.3926585095
# 83.4927697442
# 83.5928809789
# 83.6929922136
# 83.7931034483
# 83.893214683
# 83.9933259177
# 84.0934371524
# 84.1935483871
# 84.2936596218
# 84.3937708565
# 84.4938820912
# 84.5939933259
# 84.6941045606
# 84.7942157953
# 84.89432703
# 84.9944382647
# 85.0945494994
# 85.1946607341
# 85.2947719689
# 85.3948832036
# 85.4949944383
# 85.595105673
# 85.6952169077
# 85.7953281424
# 85.8954393771
# 85.9955506118
# 86.0956618465
# 86.1957730812
# 86.2958843159
# 86.3959955506
# 86.4961067853
# 86.59621802
# 86.6963292547
# 86.7964404894
# 86.8965517241
# 86.9966629588
# 87.0967741935
# 87.1968854283
# 87.296996663
# 87.3971078977
# 87.4972191324
# 87.5973303671
# 87.6974416018
# 87.7975528365
# 87.8976640712
# 87.9977753059
# 88.0978865406
# 88.1979977753
# 88.29810901
# 88.3982202447
# 88.4983314794
# 88.5984427141
# 88.6985539488
# 88.7986651835
# 88.8987764182
# 88.9988876529
# 89.0989988877
# 89.1991101224
# 89.2992213571
# 89.3993325918
# 89.4994438265
# 89.5995550612
# 89.6996662959
# 89.7997775306
# 89.8998887653
# 90.0

# %%
c = 1500.0 # speed of sound

""" n is the number of points """
def sphere_TS2(radius,n,frequency):
    N = 2*trunc(n/2) + 1    # I want an odd number
    lamda = c/frequency
    k = 2*pi/lamda
    xs = np.linspace(-radius,radius,N)
    ys = np.linspace(-radius,radius,N)
    elems = np.zeros((N,N), dtype = np.complex128)      # element contributions
    pixarea = 4*radius*radius/(N*N)    
    """
    print 'n',n
    print 'N',N
    print 'radius',radius
    print 'freq',frequency
    print 'lambda', lamda
    print 'k',k
    """
    print 'freq',frequency
    print 'xs', xs
    print 'ys',ys

    
    #elems = np.zeros((N,N), dtype = np.complex64)      # element contributions
    for i in range(N):
        x = xs[i]
        for j in range(N):
            y = ys[j]
            if inrange(radius,x,y):
                try:
#                    a = projarea(x,y)
                    a = pixarea*cosfi(radius,x,y)
#                    a = pixarea
                    val = a/lamda  # intensiteten (varför 4*?)
                    phase = -2*k*(radius-z(radius,x,y))
                    elems[i,j] = complex(val*cos(phase), val*sin(phase))
                except:
                    print x,y,a
    print 'elem(0,0)', elems[n/2,n/2]                
    return abs(np.sum(elems))**2

n = 2000
r = 2.0
frequency = 2000
print 'z',z(r,2,0)

print sphere_TS2(r,n,frequency)
# Out:
# z 0.0
# freq 2000
# xs [-2.    -1.998 -1.996 ...,  1.996  1.998  2.   ]
# ys [-2.    -1.998 -1.996 ...,  1.996  1.998  2.   ]
# elem(0,0) (5.32800399733e-06-0j)
# 0.995595993445
